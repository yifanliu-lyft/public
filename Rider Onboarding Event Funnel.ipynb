# %%
import datetime
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, HiveContext


from pyspark.sql.functions import (
    col,
    split
)

spark_context =SparkContext.getOrCreate()
from pyspark.sql import SQLContext
spark = SparkSession.builder \
    .master("yarn") \
    .appName("AspectDetector") \
    .enableHiveSupport() \
    .getOrCreate()

sqlContext = SQLContext(spark)

# Edit S3 Paths here:
s3_bucket = "data-team"
s3_subpath = "yifanliu"
s3_fullpath = "s3://" + s3_bucket + "/" + s3_subpath + "/"

print(s3_fullpath)
# Out:
# s3://data-team/yifanliu/

# %%
#change parameter here
today = datetime.datetime.now()
schema='yifanliu'
temp_event_funnel='temp_rider_onboarding_funnel_events'
output_path=s3_fullpath+temp_event_funnel
#visit_temp='tablename=temp_rider_onboarding_funnel_events'
lookback=60 #read data lookback window

# %%
def write_s3_partitioned_parquet_overwrite_dss_eventType(spark, df, suffix, schema, path):
    ds_distincts = df.select('ds').distinct().collect()
    events = df.select('event_name').distinct().collect()
    print(ds_distincts)
    print(events)

    for row in ds_distincts:
        for r2 in events:
            ds = row['ds']
            event=r2['event_name']
            s3_path = '{}/ds={}/event_name={}'.format(path, ds,event)

            print('\nSaving ds: {} event: {}, to: {}'.format(ds, event, s3_path))

            temp_df = df.filter(df.ds == ds).filter(df.event_name==event).drop("ds").drop("event_name")

            hql = """
                ALTER TABLE {}.{} DROP IF EXISTS
                  PARTITION (ds='{}',event_name='{}')
            """.format(schema, suffix, ds, event)

            print(hql)

            spark.sql(hql)

            temp_df.write \
                   .mode("overwrite") \
                   .parquet(s3_path)

            hql = """
                ALTER TABLE {}.{} ADD IF NOT EXISTS
                  PARTITION (ds='{}',event_name='{}')
                   LOCATION '{}'
            """.format(schema, suffix, ds,event, s3_path)

            print('Running\n {}'.format(hql))
            spark.sql(hql)

    print('\nAll S3 writes complete!')
    return

# %%
read_benefit_redeemed="""select 
'benefit_redeemed' as event_name,
  occurred_at,
  user_lyft_id, 
  ride_program_customer_id, 
  coupon_code, 
  ride_program_benefit_id,  
  claim_source source,
  ds
from default.event_rideprograms_benefit_redeemed
where ds >= CAST(date_add('{date}',-{lookback}) as STRING) and ds <= cast('{date}' as string)
""".format(date=today, lookback=lookback)

#print(read_benefit_redeemed)

benefit_redeemed = spark.sql(read_benefit_redeemed)

#benefit_redeemed.show()

write_s3_partitioned_parquet_overwrite_dss_eventType(spark, benefit_redeemed, temp_event_funnel, schema, output_path)

#benefit_redeemed.createOrReplaceTempView('benefit_redeemed_t')
# Out:
# [Row(ds='2021-01-19'), Row(ds='2021-02-09'), Row(ds='2021-01-24'), Row(ds='2021-01-22'), Row(ds='2020-12-28'), Row(ds='2021-02-21'), Row(ds='2021-02-03'), Row(ds='2021-01-13'), Row(ds='2021-02-10'), Row(ds='2020-12-30'), Row(ds='2021-01-21'), Row(ds='2021-02-11'), Row(ds='2021-02-07'), Row(ds='2021-02-06'), Row(ds='2021-01-11'), Row(ds='2021-01-25'), Row(ds='2021-02-19'), Row(ds='2021-02-04'), Row(ds='2021-02-08'), Row(ds='2021-01-29'), Row(ds='2021-01-18'), Row(ds='2021-02-24'), Row(ds='2021-02-01'), Row(ds='2021-02-16'), Row(ds='2020-12-29'), Row(ds='2021-02-13'), Row(ds='2021-01-09'), Row(ds='2020-12-31'), Row(ds='2021-01-10'), Row(ds='2021-01-28'), Row(ds='2021-02-15'), Row(ds='2021-01-16'), Row(ds='2021-01-23'), Row(ds='2021-02-25'), Row(ds='2021-02-17'), Row(ds='2021-01-20'), Row(ds='2021-02-02'), Row(ds='2021-02-20'), Row(ds='2021-01-06'), Row(ds='2021-01-17'), Row(ds='2021-01-31'), Row(ds='2021-02-26'), Row(ds='2021-01-30'), Row(ds='2021-01-12'), Row(ds='2021-01-27'), Row(ds='2021-01-15'), Row(ds='2021-02-12'), Row(ds='2021-02-14'), Row(ds='2021-01-04'), Row(ds='2021-02-22'), Row(ds='2021-02-23'), Row(ds='2021-01-01'), Row(ds='2021-01-07'), Row(ds='2021-01-14'), Row(ds='2021-01-26'), Row(ds='2021-01-02'), Row(ds='2021-02-18'), Row(ds='2021-01-03'), Row(ds='2021-02-05'), Row(ds='2021-01-05'), Row(ds='2021-01-08')]
# [Row(event_name='benefit_redeemed')]
#
# Saving ds: 2021-01-19 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-19/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-19',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-19',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-19/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-09 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-09',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-09',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-24 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-24/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-24',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-24',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-24/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-22 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-22/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-22',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-22',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-22/event_name=benefit_redeemed'
#
#
# Saving ds: 2020-12-28 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-28/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-28',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-28',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-28/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-21 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-21/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-21',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-21',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-21/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-03 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-03/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-03',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-03',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-03/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-13 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-13/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-13',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-13',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-13/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-10 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-10/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-10',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-10',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-10/event_name=benefit_redeemed'
#
#
# Saving ds: 2020-12-30 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-30/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-30',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-30',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-30/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-21 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-21/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-21',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-21',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-21/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-11 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-11/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-11',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-11',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-11/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-07 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-07',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-07',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-06 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-06',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-06',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-11 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-11/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-11',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-11',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-11/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-25 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-25/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-25',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-25',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-25/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-19 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-19/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-19',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-19',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-19/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-04 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-04/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-04',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-04',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-04/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-08 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-08',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-08',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-29 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-29/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-29',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-29',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-29/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-18 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-18/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-18',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-18',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-18/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-24 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-24/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-24',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-24',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-24/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-01 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-01/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-01',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-01',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-01/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-16 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-16/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-16',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-16',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-16/event_name=benefit_redeemed'
#
#
# Saving ds: 2020-12-29 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-29/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-29',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-29',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-29/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-13 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-13/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-13',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-13',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-13/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-09 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-09/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-09',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-09',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-09/event_name=benefit_redeemed'
#
#
# Saving ds: 2020-12-31 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-31/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-31',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-31',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-31/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-10 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-10/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-10',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-10',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-10/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-28 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-28/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-28',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-28',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-28/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-15 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-15/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-15',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-15',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-15/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-16 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-16/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-16',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-16',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-16/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-23 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-23/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-23',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-23',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-23/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-25 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-25/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-25',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-25',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-25/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-17 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-17/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-17',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-17',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-17/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-20 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-20/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-20',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-20',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-20/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-02 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-02/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-02',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-02',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-02/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-20 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-20/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-20',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-20',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-20/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-06 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-06/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-06',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-06',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-06/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-17 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-17/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-17',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-17',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-17/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-31 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-31/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-31',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-31',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-31/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-26 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-26/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-26',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-26',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-26/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-30 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-30/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-30',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-30',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-30/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-12 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-12/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-12',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-12',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-12/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-27 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-27/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-27',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-27',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-27/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-15 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-15/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-15',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-15',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-15/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-12 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-12/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-12',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-12',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-12/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-14 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-14/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-14',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-14',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-14/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-04 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-04/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-04',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-04',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-04/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-22 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-22/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-22',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-22',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-22/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-23 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-23/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-23',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-23',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-23/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-01 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-01/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-01',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-01',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-01/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-07 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-07/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-07',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-07',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-07/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-14 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-14/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-14',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-14',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-14/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-26 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-26/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-26',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-26',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-26/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-02 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-02/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-02',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-02',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-02/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-18 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-18/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-18',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-18',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-18/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-03 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-03/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-03',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-03',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-03/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-02-05 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-05/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-05',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-05',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-05/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-05 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-05/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-05',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-05',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-05/event_name=benefit_redeemed'
#
#
# Saving ds: 2021-01-08 event: benefit_redeemed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-08/event_name=benefit_redeemed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-08',event_name='benefit_redeemed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-08',event_name='benefit_redeemed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-08/event_name=benefit_redeemed'
#
#
# All S3 writes complete!

# %%
read_invites_sent = """
SELECT 
'invites_sent' as event_name,
occurred_at,
       user_id as user_lyft_id,
       ride_program_customer_id,
       'N/A' as coupon_code,
       -1 as ride_program_benefit_id,
       'N/A' as source,
       rbcs.ds
  FROM default.event_rideprograms_benefit_communication_sent rbcs
  join enterprise.dim_ride_program_customers rpc
    on rbcs.ride_program_customer_id = rpc.rideprogram_customer_id
 WHERE rbcs.ds >= CAST(date_add('{date}',-{lookback}) as STRING) and rbcs.ds <= cast('{date}' as string)
   and date(rpc.ds) = current_date - interval '2' day
   and (is_sms_sent = True or is_push_notification_sent = True)
   and action_type = 'invite'
""".format(date=today, lookback=lookback)

#print(read_invites_sent)

invites_sent = spark.sql(read_invites_sent)

#invites_sent.show()

write_s3_partitioned_parquet_overwrite_dss_eventType(spark, invites_sent, temp_event_funnel, schema, output_path)



#invites_sent.createOrReplaceTempView('invites_sent_t')
# Out:
# [Row(ds='2021-02-09'), Row(ds='2021-01-19'), Row(ds='2020-12-28'), Row(ds='2021-01-24'), Row(ds='2021-01-22'), Row(ds='2021-01-13'), Row(ds='2021-02-03'), Row(ds='2021-02-21'), Row(ds='2021-02-11'), Row(ds='2021-01-21'), Row(ds='2020-12-30'), Row(ds='2021-02-07'), Row(ds='2021-02-06'), Row(ds='2021-02-10'), Row(ds='2021-01-25'), Row(ds='2021-01-11'), Row(ds='2021-02-24'), Row(ds='2021-02-19'), Row(ds='2021-02-08'), Row(ds='2021-01-18'), Row(ds='2021-02-01'), Row(ds='2021-02-16'), Row(ds='2021-02-13'), Row(ds='2021-01-09'), Row(ds='2021-01-29'), Row(ds='2021-02-04'), Row(ds='2021-01-28'), Row(ds='2021-02-25'), Row(ds='2020-12-29'), Row(ds='2021-02-15'), Row(ds='2021-01-16'), Row(ds='2021-01-10'), Row(ds='2020-12-31'), Row(ds='2021-01-23'), Row(ds='2021-02-02'), Row(ds='2021-01-20'), Row(ds='2021-02-17'), Row(ds='2021-02-26'), Row(ds='2021-01-31'), Row(ds='2021-01-30'), Row(ds='2021-02-22'), Row(ds='2021-01-15'), Row(ds='2021-01-04'), Row(ds='2021-02-23'), Row(ds='2021-02-20'), Row(ds='2021-01-17'), Row(ds='2021-01-06'), Row(ds='2021-01-12'), Row(ds='2021-01-01'), Row(ds='2021-01-07'), Row(ds='2021-01-27'), Row(ds='2021-01-14'), Row(ds='2021-02-14'), Row(ds='2021-02-12'), Row(ds='2021-01-02'), Row(ds='2021-02-05'), Row(ds='2021-01-26'), Row(ds='2021-02-18'), Row(ds='2021-01-05'), Row(ds='2021-01-08'), Row(ds='2021-01-03')]
# [Row(event_name='invites_sent')]
#
# Saving ds: 2021-02-09 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-09',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-09',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=invites_sent'
#
#
# Saving ds: 2021-01-19 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-19/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-19',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-19',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-19/event_name=invites_sent'
#
#
# Saving ds: 2020-12-28 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-28/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-28',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-28',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-28/event_name=invites_sent'
#
#
# Saving ds: 2021-01-24 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-24/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-24',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-24',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-24/event_name=invites_sent'
#
#
# Saving ds: 2021-01-22 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-22/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-22',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-22',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-22/event_name=invites_sent'
#
#
# Saving ds: 2021-01-13 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-13/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-13',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-13',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-13/event_name=invites_sent'
#
#
# Saving ds: 2021-02-03 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-03/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-03',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-03',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-03/event_name=invites_sent'
#
#
# Saving ds: 2021-02-21 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-21/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-21',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-21',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-21/event_name=invites_sent'
#
#
# Saving ds: 2021-02-11 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-11/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-11',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-11',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-11/event_name=invites_sent'
#
#
# Saving ds: 2021-01-21 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-21/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-21',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-21',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-21/event_name=invites_sent'
#
#
# Saving ds: 2020-12-30 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-30/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-30',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-30',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-30/event_name=invites_sent'
#
#
# Saving ds: 2021-02-07 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-07',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-07',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=invites_sent'
#
#
# Saving ds: 2021-02-06 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-06',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-06',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=invites_sent'
#
#
# Saving ds: 2021-02-10 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-10/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-10',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-10',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-10/event_name=invites_sent'
#
#
# Saving ds: 2021-01-25 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-25/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-25',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-25',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-25/event_name=invites_sent'
#
#
# Saving ds: 2021-01-11 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-11/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-11',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-11',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-11/event_name=invites_sent'
#
#
# Saving ds: 2021-02-24 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-24/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-24',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-24',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-24/event_name=invites_sent'
#
#
# Saving ds: 2021-02-19 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-19/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-19',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-19',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-19/event_name=invites_sent'
#
#
# Saving ds: 2021-02-08 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-08',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-08',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=invites_sent'
#
#
# Saving ds: 2021-01-18 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-18/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-18',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-18',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-18/event_name=invites_sent'
#
#
# Saving ds: 2021-02-01 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-01/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-01',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-01',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-01/event_name=invites_sent'
#
#
# Saving ds: 2021-02-16 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-16/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-16',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-16',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-16/event_name=invites_sent'
#
#
# Saving ds: 2021-02-13 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-13/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-13',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-13',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-13/event_name=invites_sent'
#
#
# Saving ds: 2021-01-09 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-09/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-09',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-09',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-09/event_name=invites_sent'
#
#
# Saving ds: 2021-01-29 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-29/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-29',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-29',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-29/event_name=invites_sent'
#
#
# Saving ds: 2021-02-04 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-04/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-04',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-04',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-04/event_name=invites_sent'
#
#
# Saving ds: 2021-01-28 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-28/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-28',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-28',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-28/event_name=invites_sent'
#
#
# Saving ds: 2021-02-25 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-25/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-25',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-25',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-25/event_name=invites_sent'
#
#
# Saving ds: 2020-12-29 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-29/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-29',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-29',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-29/event_name=invites_sent'
#
#
# Saving ds: 2021-02-15 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-15/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-15',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-15',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-15/event_name=invites_sent'
#
#
# Saving ds: 2021-01-16 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-16/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-16',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-16',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-16/event_name=invites_sent'
#
#
# Saving ds: 2021-01-10 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-10/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-10',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-10',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-10/event_name=invites_sent'
#
#
# Saving ds: 2020-12-31 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-31/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2020-12-31',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2020-12-31',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2020-12-31/event_name=invites_sent'
#
#
# Saving ds: 2021-01-23 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-23/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-23',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-23',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-23/event_name=invites_sent'
#
#
# Saving ds: 2021-02-02 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-02/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-02',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-02',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-02/event_name=invites_sent'
#
#
# Saving ds: 2021-01-20 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-20/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-20',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-20',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-20/event_name=invites_sent'
#
#
# Saving ds: 2021-02-17 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-17/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-17',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-17',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-17/event_name=invites_sent'
#
#
# Saving ds: 2021-02-26 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-26/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-26',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-26',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-26/event_name=invites_sent'
#
#
# Saving ds: 2021-01-31 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-31/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-31',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-31',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-31/event_name=invites_sent'
#
#
# Saving ds: 2021-01-30 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-30/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-30',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-30',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-30/event_name=invites_sent'
#
#
# Saving ds: 2021-02-22 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-22/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-22',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-22',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-22/event_name=invites_sent'
#
#
# Saving ds: 2021-01-15 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-15/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-15',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-15',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-15/event_name=invites_sent'
#
#
# Saving ds: 2021-01-04 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-04/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-04',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-04',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-04/event_name=invites_sent'
#
#
# Saving ds: 2021-02-23 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-23/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-23',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-23',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-23/event_name=invites_sent'
#
#
# Saving ds: 2021-02-20 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-20/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-20',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-20',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-20/event_name=invites_sent'
#
#
# Saving ds: 2021-01-17 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-17/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-17',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-17',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-17/event_name=invites_sent'
#
#
# Saving ds: 2021-01-06 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-06/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-06',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-06',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-06/event_name=invites_sent'
#
#
# Saving ds: 2021-01-12 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-12/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-12',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-12',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-12/event_name=invites_sent'
#
#
# Saving ds: 2021-01-01 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-01/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-01',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-01',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-01/event_name=invites_sent'
#
#
# Saving ds: 2021-01-07 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-07/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-07',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-07',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-07/event_name=invites_sent'
#
#
# Saving ds: 2021-01-27 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-27/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-27',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-27',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-27/event_name=invites_sent'
#
#
# Saving ds: 2021-01-14 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-14/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-14',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-14',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-14/event_name=invites_sent'
#
#
# Saving ds: 2021-02-14 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-14/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-14',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-14',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-14/event_name=invites_sent'
#
#
# Saving ds: 2021-02-12 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-12/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-12',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-12',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-12/event_name=invites_sent'
#
#
# Saving ds: 2021-01-02 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-02/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-02',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-02',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-02/event_name=invites_sent'
#
#
# Saving ds: 2021-02-05 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-05/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-05',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-05',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-05/event_name=invites_sent'
#
#
# Saving ds: 2021-01-26 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-26/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-26',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-26',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-26/event_name=invites_sent'
#
#
# Saving ds: 2021-02-18 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-18/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-18',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-18',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-18/event_name=invites_sent'
#
#
# Saving ds: 2021-01-05 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-05/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-05',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-05',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-05/event_name=invites_sent'
#
#
# Saving ds: 2021-01-08 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-08/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-08',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-08',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-08/event_name=invites_sent'
#
#
# Saving ds: 2021-01-03 event: invites_sent, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-03/event_name=invites_sent
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-01-03',event_name='invites_sent')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-01-03',event_name='invites_sent')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-01-03/event_name=invites_sent'
#
#
# All S3 writes complete!

# %%
read_invite_clicked = """
select 
'invite_clicked' as event_name,
occurred_at,
user_id user_lyft_id,
-1 as ride_program_customer_id,
'N/A' as coupon_code,
-1 as ride_program_benefit_id,
split(parameter,'lp/')[1] as source,
ds
from default.event_client_action
where ds >= CAST(date_add('{date}',-{lookback}) as STRING) and ds <= cast('{date}' as string)
   AND action = 'handle_deep_link'
   AND type = 'result'
   AND parameter like 'https://lyft.com/lp/%'
""".format(date=today, lookback=lookback)

#print(read_invite_clicked)

invite_clicked = spark.sql(read_invite_clicked)
invite_clicked.show()
write_s3_partitioned_parquet_overwrite_dss_eventType(spark, invite_clicked, temp_event_funnel, schema, output_path)

# %%
read_ux_events="""select 
        CONCAT('ux_',type) as event_name,
        occurred_at,
       user_id user_lyft_id,
       'N/A' as ride_program_customer_id,
'N/A' as coupon_code,
'N/A' as ride_program_benefit_id,
       element as source,
       ds
  from default.event_client_ux ux
  WHERE ds >= CAST(date_add('{date}',-{lookback}) as STRING) and ds <= cast('{date}' as string)
    AND (type = 'displayed' or type = 'tapped')
    AND (element = 'welcome_modal' or element = 'welcome_v2_modal' or element = 'program_details_prompt' or element = 'welcome_v2_modal_continue_button'
          or element = 'welcome_modal_done_button' or element = 'program_details_v2_done_button')
""".format(date=today, lookback=lookback)

ux_events = spark.sql(read_ux_events)
ux_events.show()
write_s3_partitioned_parquet_overwrite_dss_eventType(spark, ux_events, temp_event_funnel, schema, output_path)

# %% [markdown]
# - create table first
#
# ```drop table yifanliu.temp_rider_onboarding_funnel_events  ;
# create external table yifanliu.temp_rider_onboarding_funnel_events
# (
# occurred_at timestamp,
# user_lyft_id bigint,
# ride_program_customer_id bigint,
# coupon_code string,
# ride_program_benefit_id bigint,
# source string
# )
# partitioned by(ds string,event_name string)
# STORED AS PARQUET
# LOCATION
#   's3://data-team/users/yifanliu/temp_rider_onboarding_funnel_events'
#   TBLPROPERTIES ('PARQUET.COMPRESS'='SNAPPY');*/```
