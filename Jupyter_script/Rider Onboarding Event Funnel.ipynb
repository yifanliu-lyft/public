# %% [markdown]
# - create table first
#
# ```drop table yifanliu.temp_rider_onboarding_funnel_events  ;
# create external table yifanliu.temp_rider_onboarding_funnel_events
# (
# occurred_at timestamp,
# user_lyft_id bigint,
# ride_program_customer_id bigint,
# coupon_code string,
# ride_program_benefit_id bigint,
# source string
# )
# partitioned by(ds string,event_name string)
# STORED AS PARQUET
# LOCATION
#   's3://data-team/users/yifanliu/temp_rider_onboarding_funnel_events'
#   TBLPROPERTIES ('PARQUET.COMPRESS'='SNAPPY');*/```

# %%
import datetime
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, HiveContext
from datetime import timedelta


from pyspark.sql.functions import (
    col,
    split
)

spark_context =SparkContext.getOrCreate()
from pyspark.sql import SQLContext
spark = SparkSession.builder \
    .master("yarn") \
    .appName("AspectDetector") \
    .enableHiveSupport() \
    .getOrCreate()

sqlContext = SQLContext(spark)

# Edit S3 Paths here:
s3_bucket = "data-team"
s3_subpath = "yifanliu"
s3_fullpath = "s3://" + s3_bucket + "/" + s3_subpath + "/"

print(s3_fullpath)
# Out:
# s3://data-team/yifanliu/

# %%
#change parameter here
today = datetime.date.today()#datetime.date(2020, 12, 31)#datetime.datetime.now()
schema='yifanliu'
temp_event_funnel='temp_rider_onboarding_funnel_events'
output_path=s3_fullpath+temp_event_funnel
#visit_temp='tablename=temp_rider_onboarding_funnel_events'
lookback=60 #read data lookback window

# %%
def write_s3_partitioned_parquet_overwrite_dss_eventType(spark, df, suffix, schema, path):
    ds_distincts = df.select('ds').distinct().collect()
    events = df.select('event_name').distinct().collect()
    print(ds_distincts)
    print(events)

    for row in ds_distincts:
        for r2 in events:
            ds = row['ds']
            event=r2['event_name']
            s3_path = '{}/ds={}/event_name={}'.format(path, ds,event)

            print('\nSaving ds: {} event: {}, to: {}'.format(ds, event, s3_path))

            temp_df = df.filter(df.ds == ds).filter(df.event_name==event).drop("ds").drop("event_name")

            hql = """
                ALTER TABLE {}.{} DROP IF EXISTS
                  PARTITION (ds='{}',event_name='{}')
            """.format(schema, suffix, ds, event)

            print(hql)

            spark.sql(hql)

            temp_df.write \
                   .mode("overwrite") \
                   .parquet(s3_path)

            hql = """
                ALTER TABLE {}.{} ADD IF NOT EXISTS
                  PARTITION (ds='{}',event_name='{}')
                   LOCATION '{}'
            """.format(schema, suffix, ds,event, s3_path)

            print('Running\n {}'.format(hql))
            spark.sql(hql)

    print('\nAll S3 writes complete!')
    return

# %%
read_benefit_redeemed="""select 
'benefit_redeemed' as event_name,
  occurred_at,
  user_lyft_id, 
  ride_program_customer_id, 
  coupon_code, 
  ride_program_benefit_id,  
  claim_source source,
  ds
from default.event_rideprograms_benefit_redeemed
where ds >= CAST(date_add('{date}',-{lookback}) as STRING) and ds <= cast('{date}' as string)
""".format(date=today, lookback=lookback)

#print(read_benefit_redeemed)

benefit_redeemed = spark.sql(read_benefit_redeemed)

#benefit_redeemed.show()

write_s3_partitioned_parquet_overwrite_dss_eventType(spark, benefit_redeemed, temp_event_funnel, schema, output_path)

#benefit_redeemed.createOrReplaceTempView('benefit_redeemed_t')

# %%
read_invites_sent = """
SELECT 
'invites_sent' as event_name,
occurred_at,
       user_id as user_lyft_id,
       ride_program_customer_id,
       'N/A' as coupon_code,
       -1 as ride_program_benefit_id,
       'N/A' as source,
       rbcs.ds
  FROM default.event_rideprograms_benefit_communication_sent rbcs
  join enterprise.dim_ride_program_customers rpc
    on rbcs.ride_program_customer_id = rpc.rideprogram_customer_id
 WHERE rbcs.ds >= CAST(date_add('{date}',-{lookback}) as STRING) and rbcs.ds <= cast('{date}' as string)
   and date(rpc.ds) = current_date - interval '2' day
   and (is_sms_sent = True or is_push_notification_sent = True)
   and action_type = 'invite'
""".format(date=today, lookback=lookback)

#print(read_invites_sent)

invites_sent = spark.sql(read_invites_sent)

#invites_sent.show()

write_s3_partitioned_parquet_overwrite_dss_eventType(spark, invites_sent, temp_event_funnel, schema, output_path)



#invites_sent.createOrReplaceTempView('invites_sent_t')

# %%
#today = datetime.date(2020,1,26)
#lookback=0
d=today#datetime.date(2020,10,31)

while d >= (today - timedelta(days=lookback)):
    read_invite_clicked = """
    select 
    'invite_clicked' as event_name,
    occurred_at,
    user_id user_lyft_id,
    -1 as ride_program_customer_id,
    'N/A' as coupon_code,
    -1 as ride_program_benefit_id,
    split(parameter,'lp/')[1] as source,
    ds
    from default.event_client_action
    where ds >= CAST(date_add('{date}',-{lookback}) as STRING) and ds <= cast('{date}' as string)
       AND action = 'handle_deep_link'
       AND type = 'result'
       AND parameter like 'https://lyft.com/lp/%'
    """.format(date=d, lookback=1)

    print(read_invite_clicked)

    invite_clicked = spark.sql(read_invite_clicked)
    invite_clicked.show()
    
    if invite_clicked.head() is not None:
        write_s3_partitioned_parquet_overwrite_dss_eventType(spark, invite_clicked, temp_event_funnel, schema, output_path)
    d = d - timedelta(days=1)
    print(d)

# %%
d=today#datetime.date(2021,2,20)

while d >= (today - timedelta(days=lookback)):
    print(d)
    read_ux_events="""select 
        CONCAT('ux_',type) as event_name,
        occurred_at,
       user_id user_lyft_id,
       -1 as ride_program_customer_id,
        'N/A' as coupon_code,
        -1 as ride_program_benefit_id,
               element as source,
               ds
          from default.event_client_ux ux
          WHERE ds >= CAST(date_add('{date}',-{lookback}) as STRING) and ds <= cast('{date}' as string)
            AND (type = 'displayed' or type = 'tapped')
            AND (element = 'welcome_modal' or element = 'welcome_v2_modal' or element = 'program_details_prompt' or element = 'welcome_v2_modal_continue_button'
                  or element = 'welcome_modal_done_button' or element = 'program_details_v2_done_button')
        """.format(date=d, lookback=1)

    ux_events = spark.sql(read_ux_events)

    ux_events.show()
    
    if ux_events.head() is not None:

        write_s3_partitioned_parquet_overwrite_dss_eventType(spark, ux_events, temp_event_funnel, schema, output_path)
    
    d = d - timedelta(days=1)
    print(d)
# Out:
# 2021-04-08
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |ux_displayed|2021-04-08 18:47:...|1213445896234781166|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |   ux_tapped|2021-04-08 18:47:...|1213445896234781166|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |   ux_tapped|2021-04-01 04:33:...|1499748533210134572|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |   ux_tapped|2021-04-08 21:02:...|1243785399177575368|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |ux_displayed|2021-04-01 04:32:...|1499748533210134572|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |ux_displayed|2021-04-08 21:02:...|1475127098122541096|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |   ux_tapped|2021-04-08 21:04:...|1061155919323477228|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |ux_displayed|2021-04-08 21:02:...|1243785399177575368|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |   ux_tapped|2021-04-08 21:02:...|1475127098122541096|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |ux_displayed|2021-04-08 21:04:...|1061155919323477228|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |ux_displayed|2021-04-08 20:02:...|1070571346505673658|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |   ux_tapped|2021-04-08 20:02:...|1070571346505673658|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |ux_displayed|2021-04-08 20:05:...|1227252741859788852|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |ux_displayed|2021-04-08 19:02:...|1260328917471285706|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |   ux_tapped|2021-04-08 20:05:...|1227252741859788852|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |ux_displayed|2021-04-08 18:03:...| 781130027927530676|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |   ux_tapped|2021-04-08 18:05:...| 813209114658758086|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |ux_displayed|2021-04-08 18:06:...|1356595274822636242|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# |   ux_tapped|2021-04-08 18:03:...|1523836760888568526|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-08|
# |ux_displayed|2021-04-08 18:07:...|1356595274822636242|                      -1|        N/A|                     -1|       welcome_modal|2021-04-08|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-04-08'), Row(ds='2021-04-07')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-04-08 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-08/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-08',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-08',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-08/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-08 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-08/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-08',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-08',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-08/event_name=ux_displayed'
#
#
# Saving ds: 2021-04-07 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-07 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-04-07
# 2021-04-07
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |ux_displayed|2021-04-06 15:51:...|1522048199100020832|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |   ux_tapped|2021-04-06 15:52:...| 911751093022134018|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |   ux_tapped|2021-04-06 15:19:...|1112246909296960938|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |ux_displayed|2021-04-01 16:27:...|1126893975995754922|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |ux_displayed|2021-04-06 15:25:...|1526511822130486042|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |ux_displayed|2021-04-06 15:42:...|1322896139775590530|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |   ux_tapped|2021-04-06 15:55:...|1158138580498005786|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |ux_displayed|2021-04-06 15:59:...|1348774631682173794|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |ux_displayed|2021-04-06 15:52:...| 911751093022134018|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |ux_displayed|2021-04-06 15:17:...|1106043055382662504|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |   ux_tapped|2021-04-06 15:40:...|1024632524008167052|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |ux_displayed|2021-04-06 15:44:...|1454210097140020210|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |ux_displayed|2021-04-06 15:41:...| 845216276130614644|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |   ux_tapped|2021-04-06 15:41:...| 845216276130614644|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |   ux_tapped|2021-04-06 15:51:...|1522048199100020832|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |   ux_tapped|2021-04-06 15:42:...|1001077083225299884|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |   ux_tapped|2021-04-06 15:42:...|1322896139775590530|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |ux_displayed|2021-04-01 16:27:...|1126893975995754922|                      -1|        N/A|                     -1|       welcome_modal|2021-04-06|
# |   ux_tapped|2021-04-06 15:17:...|1228504404558965168|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# |   ux_tapped|2021-04-06 15:58:...| 975252585689214810|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-06|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-04-06'), Row(ds='2021-04-07')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-04-06 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-06 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_displayed'
#
#
# Saving ds: 2021-04-07 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-07 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-07',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-07/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-04-06
# 2021-04-06
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |   ux_tapped|2021-04-05 19:25:...|1181199834966055016|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |ux_displayed|2021-04-05 19:51:...|1503159849623433810|                      -1|        N/A|                     -1|       welcome_modal|2021-04-05|
# |   ux_tapped|2021-04-05 19:53:...|1040042593112963418|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |ux_displayed|2021-04-01 23:03:...|1211269088928026700|                      -1|        N/A|                     -1|       welcome_modal|2021-04-05|
# |ux_displayed|2021-04-05 19:01:...|1434487019764773652|                      -1|        N/A|                     -1|       welcome_modal|2021-04-05|
# |ux_displayed|2021-04-05 19:04:...| 633830733883046456|                      -1|        N/A|                     -1|program_details_p...|2021-04-05|
# |ux_displayed|2021-04-05 19:52:...|1098857994918282130|                      -1|        N/A|                     -1|       welcome_modal|2021-04-05|
# |   ux_tapped|2021-04-01 01:51:...| 916545414416883210|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |ux_displayed|2021-04-05 19:51:...|1040042593112963418|                      -1|        N/A|                     -1|       welcome_modal|2021-04-05|
# |ux_displayed|2021-04-05 19:38:...|1526205931962900996|                      -1|        N/A|                     -1|program_details_p...|2021-04-05|
# |ux_displayed|2021-04-05 20:06:...|1525557896466114782|                      -1|        N/A|                     -1|       welcome_modal|2021-04-05|
# |   ux_tapped|2021-04-05 19:02:...|1472345764070971978|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |   ux_tapped|2021-04-05 19:21:...|1384095865852835986|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |   ux_tapped|2021-04-05 20:52:...|1060418595001395228|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |   ux_tapped|2021-04-05 20:32:...|1060418595001395228|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |ux_displayed|2021-04-05 19:30:...|1526190291466054484|                      -1|        N/A|                     -1|program_details_p...|2021-04-05|
# |ux_displayed|2021-04-05 20:06:...|1525557896466114782|                      -1|        N/A|                     -1|program_details_p...|2021-04-05|
# |ux_displayed|2021-04-05 20:26:...|1060418595001395228|                      -1|        N/A|                     -1|       welcome_modal|2021-04-05|
# |   ux_tapped|2021-04-05 19:39:...|1526205931962900996|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# |   ux_tapped|2021-04-05 19:34:...|1302053652901087910|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-05|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-04-06'), Row(ds='2021-04-05')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-04-06 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-06 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-06',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-06/event_name=ux_displayed'
#
#
# Saving ds: 2021-04-05 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-05 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-04-05
# 2021-04-05
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |ux_displayed|2021-04-04 00:45:...|1416661924158744586|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |ux_displayed|2021-04-04 00:32:...|1346190007009686416|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |ux_displayed|2021-04-04 00:21:...|1340846232281066330|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:14:...|1060109541919745134|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:06:...|1334072825002031140|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:52:...|1198529566186164290|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:52:...|1198529566186164290|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:39:...| 882379003628390896|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:57:...|1218279081978373068|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:06:...|1334072825002031140|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:18:...|1498857283489593950|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:19:...| 859792262858219452|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:32:...|1346190007009686416|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:45:...|1226029785979242568|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:57:...|1525533423440857208|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |ux_displayed|2021-04-04 00:39:...| 882379003628390896|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:45:...|1416661924158744586|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:44:...|1232314524408767232|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:31:...|1467700494353008812|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:51:...|1448325212698110702|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-04-05'), Row(ds='2021-04-04')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-04-05 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-05 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-05',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-05/event_name=ux_displayed'
#
#
# Saving ds: 2021-04-04 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-04 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-04-04
# 2021-04-04
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |ux_displayed|2021-04-04 00:45:...|1416661924158744586|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |ux_displayed|2021-04-04 00:32:...|1346190007009686416|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |ux_displayed|2021-04-04 00:21:...|1340846232281066330|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:14:...|1060109541919745134|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:06:...|1334072825002031140|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:52:...|1198529566186164290|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:52:...|1198529566186164290|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:39:...| 882379003628390896|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:57:...|1218279081978373068|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:06:...|1334072825002031140|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:18:...|1498857283489593950|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:19:...| 859792262858219452|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:32:...|1346190007009686416|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:45:...|1226029785979242568|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |ux_displayed|2021-04-04 00:57:...|1525533423440857208|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |ux_displayed|2021-04-04 00:39:...| 882379003628390896|                      -1|        N/A|                     -1|       welcome_modal|2021-04-04|
# |   ux_tapped|2021-04-04 00:45:...|1416661924158744586|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:44:...|1232314524408767232|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:31:...|1467700494353008812|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# |   ux_tapped|2021-04-04 00:51:...|1448325212698110702|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-04|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-04-03'), Row(ds='2021-04-04')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-04-03 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-03 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_displayed'
#
#
# Saving ds: 2021-04-04 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-04 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-04',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-04/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-04-03
# 2021-04-03
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |   ux_tapped|2021-04-02 21:22:...| 994229574280212774|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |   ux_tapped|2021-04-02 20:10:...|1405636416121633476|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |   ux_tapped|2021-04-02 21:21:...|1025861069937144760|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |   ux_tapped|2021-04-02 20:15:...| 997121315970235634|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 20:14:...| 955088652881493240|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |   ux_tapped|2021-04-02 21:33:...|1172514407881337278|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 04:13:...|1524790073905759114|                      -1|        N/A|                     -1|program_details_p...|2021-04-02|
# |   ux_tapped|2021-04-02 21:47:...|1185595392572475870|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 21:15:...|1084914179063605216|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:21:...|1025861069937144760|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |   ux_tapped|2021-04-02 21:13:...|1423685101056631792|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 21:20:...|1321673770130569950|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:52:...|1345087492737428216|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:11:...|1517874932419805514|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:36:...|1297357746597286174|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:20:...|1439845576579849030|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |   ux_tapped|2021-04-02 21:48:...|1405257363595084406|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 21:00:...|1200583603009364654|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:01:...|1000711051231741464|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:30:...|1279877828173537944|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-04-03'), Row(ds='2021-04-02')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-04-03 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-03 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-03',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-03/event_name=ux_displayed'
#
#
# Saving ds: 2021-04-02 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-02 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-04-02
# 2021-04-02
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |   ux_tapped|2021-04-02 21:22:...| 994229574280212774|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |   ux_tapped|2021-04-02 20:10:...|1405636416121633476|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |   ux_tapped|2021-04-02 21:21:...|1025861069937144760|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |   ux_tapped|2021-04-02 20:15:...| 997121315970235634|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 20:14:...| 955088652881493240|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |   ux_tapped|2021-04-02 21:33:...|1172514407881337278|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 04:13:...|1524790073905759114|                      -1|        N/A|                     -1|program_details_p...|2021-04-02|
# |   ux_tapped|2021-04-02 21:47:...|1185595392572475870|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 21:15:...|1084914179063605216|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:21:...|1025861069937144760|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |   ux_tapped|2021-04-02 21:13:...|1423685101056631792|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 21:20:...|1321673770130569950|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:52:...|1345087492737428216|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:11:...|1517874932419805514|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:36:...|1297357746597286174|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:20:...|1439845576579849030|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |   ux_tapped|2021-04-02 21:48:...|1405257363595084406|                      -1|        N/A|                     -1|welcome_modal_don...|2021-04-02|
# |ux_displayed|2021-04-02 21:00:...|1200583603009364654|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:01:...|1000711051231741464|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# |ux_displayed|2021-04-02 21:30:...|1279877828173537944|                      -1|        N/A|                     -1|       welcome_modal|2021-04-02|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-04-01'), Row(ds='2021-04-02')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-04-01 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-01/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-01',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-01',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-01/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-01 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-01/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-01',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-01',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-01/event_name=ux_displayed'
#
#
# Saving ds: 2021-04-02 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_tapped'
#
#
# Saving ds: 2021-04-02 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-04-02',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-04-02/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-04-01
# 2021-04-01
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |ux_displayed|2021-03-31 17:17:...|1436882630164951742|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |ux_displayed|2021-03-31 17:03:...|1361069924315571038|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |ux_displayed|2021-03-31 17:24:...|1314878006397565638|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |ux_displayed|2021-03-31 17:41:...| 948898997520390874|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |   ux_tapped|2021-03-31 17:48:...|1485825146953185666|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |   ux_tapped|2021-03-31 17:18:...|1322604460870046036|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |   ux_tapped|2021-03-31 17:50:...|1275063408118043036|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |   ux_tapped|2021-03-31 17:03:...|1361069924315571038|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |   ux_tapped|2021-03-31 17:46:...|1138938214430792892|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |ux_displayed|2021-03-31 17:19:...|1322604460870046036|                      -1|        N/A|                     -1|program_details_p...|2021-03-31|
# |   ux_tapped|2021-03-31 17:43:...|1380886267321995424|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |   ux_tapped|2021-03-31 17:54:...|1275063408118043036|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |ux_displayed|2021-03-31 17:59:...|1361003075423075092|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |   ux_tapped|2021-03-31 17:41:...|1196616735147759936|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |ux_displayed|2021-03-31 17:41:...|1196616735147759936|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |ux_displayed|2021-03-31 17:22:...|1446041894957179338|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |ux_displayed|2021-03-31 17:18:...|1322604460870046036|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# |   ux_tapped|2021-03-31 17:25:...|1314878006397565638|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |   ux_tapped|2021-03-31 17:55:...|1251275468522824652|                      -1|        N/A|                     -1|welcome_modal_don...|2021-03-31|
# |ux_displayed|2021-03-31 17:03:...|1361069924315571038|                      -1|        N/A|                     -1|       welcome_modal|2021-03-31|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-03-31'), Row(ds='2021-04-01')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-03-31 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-03-31/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-03-31',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
# ...
# |ux_displayed|2021-02-08 21:00:...|1085886346159054920|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |ux_displayed|2021-02-08 21:04:...| 963569681534634820|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |   ux_tapped|2021-02-08 21:24:...|1466101112910967708|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |ux_displayed|2021-02-08 21:15:...|1433610766631297830|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-02-08'), Row(ds='2021-02-09')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-02-08 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_tapped'
#
#
# Saving ds: 2021-02-08 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_displayed'
#
#
# Saving ds: 2021-02-09 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-09',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-09',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=ux_tapped'
#
#
# Saving ds: 2021-02-09 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-09',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-09',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-09/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-02-08
# 2021-02-08
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |   ux_tapped|2021-02-08 21:15:...|1433610766631297830|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |   ux_tapped|2021-02-08 21:28:...|1353556912119867592|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |ux_displayed|2021-02-08 21:04:...|1475948710173698542|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |ux_displayed|2021-02-08 21:45:...|1463096537658604122|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |   ux_tapped|2021-02-08 21:04:...|1097709900229826274|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |   ux_tapped|2021-02-08 21:57:...|1268262082173487582|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |   ux_tapped|2021-02-08 21:49:...| 846504698941436830|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |ux_displayed|2021-02-08 21:57:...|1268262082173487582|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |ux_displayed|2021-02-08 21:04:...| 963569681534634820|                      -1|        N/A|                     -1|program_details_p...|2021-02-08|
# |   ux_tapped|2020-12-17 11:08:...| 921353350656415190|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |   ux_tapped|2021-02-08 21:05:...|1433610766631297830|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |ux_displayed|2021-02-08 21:28:...|1353556912119867592|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |ux_displayed|2020-12-16 20:16:...| 921353350656415190|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |ux_displayed|2021-02-08 21:03:...|1097709900229826274|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |ux_displayed|2021-02-08 21:52:...|1096740798266314194|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |   ux_tapped|2021-02-08 21:53:...|1013434644167128450|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |ux_displayed|2021-02-08 21:00:...|1085886346159054920|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |ux_displayed|2021-02-08 21:04:...| 963569681534634820|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# |   ux_tapped|2021-02-08 21:24:...|1466101112910967708|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-08|
# |ux_displayed|2021-02-08 21:15:...|1433610766631297830|                      -1|        N/A|                     -1|       welcome_modal|2021-02-08|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-02-08'), Row(ds='2021-02-07')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-02-08 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_tapped'
#
#
# Saving ds: 2021-02-08 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-08',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-08/event_name=ux_displayed'
#
#
# Saving ds: 2021-02-07 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_tapped'
#
#
# Saving ds: 2021-02-07 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-02-07
# 2021-02-07
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |  event_name|         occurred_at|       user_lyft_id|ride_program_customer_id|coupon_code|ride_program_benefit_id|              source|        ds|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# |   ux_tapped|2021-02-07 00:15:...|1054498936326366752|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |ux_displayed|2021-02-07 00:14:...|1011559392275583876|                      -1|        N/A|                     -1|program_details_p...|2021-02-07|
# |ux_displayed|2021-02-07 00:09:...|1170664924289217302|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# |   ux_tapped|2021-02-07 00:32:...| 696562135763953158|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |   ux_tapped|2021-02-07 00:06:...|1076078389268956644|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |ux_displayed|2021-02-07 00:11:...|1144861928053747166|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# |ux_displayed|2021-02-07 00:11:...|1011559392275583876|                      -1|        N/A|                     -1|program_details_p...|2021-02-07|
# |ux_displayed|2021-02-07 00:14:...|1011559392275583876|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# |   ux_tapped|2021-02-07 00:53:...| 741382761142456322|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |   ux_tapped|2021-02-07 00:29:...|1058282956397498184|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |ux_displayed|2021-02-07 00:16:...|1011559392275583876|                      -1|        N/A|                     -1|program_details_p...|2021-02-07|
# |   ux_tapped|2021-02-07 00:08:...|1113677527121427786|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |   ux_tapped|2021-02-07 00:03:...|1504750108590891228|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |ux_displayed|2021-02-06 23:59:...|1504749517659297870|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# |ux_displayed|2021-02-07 00:11:...|1011559392275583876|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# |   ux_tapped|2021-02-06 23:59:...|1400758325722347520|                      -1|        N/A|                     -1|welcome_modal_don...|2021-02-07|
# |ux_displayed|2021-02-07 00:40:...|1418664169671438648|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# |ux_displayed|2021-02-07 00:44:...| 904754955959913894|                      -1|        N/A|                     -1|program_details_p...|2021-02-07|
# |ux_displayed|2021-02-07 00:44:...| 904754955959913894|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# |ux_displayed|2021-02-07 00:54:...|1340362033384880960|                      -1|        N/A|                     -1|       welcome_modal|2021-02-07|
# +------------+--------------------+-------------------+------------------------+-----------+-----------------------+--------------------+----------+
# only showing top 20 rows
#
# [Row(ds='2021-02-06'), Row(ds='2021-02-07')]
# [Row(event_name='ux_tapped'), Row(event_name='ux_displayed')]
#
# Saving ds: 2021-02-06 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-06',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-06',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=ux_tapped'
#
#
# Saving ds: 2021-02-06 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-06',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-06',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-06/event_name=ux_displayed'
#
#
# Saving ds: 2021-02-07 event: ux_tapped, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_tapped
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_tapped')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_tapped')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_tapped'
#
#
# Saving ds: 2021-02-07 event: ux_displayed, to: s3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_displayed
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events DROP IF EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_displayed')
#
# Running
#
#                 ALTER TABLE yifanliu.temp_rider_onboarding_funnel_events ADD IF NOT EXISTS
#                   PARTITION (ds='2021-02-07',event_name='ux_displayed')
#                    LOCATION 's3://data-team/yifanliu/temp_rider_onboarding_funnel_events/ds=2021-02-07/event_name=ux_displayed'
#
#
# All S3 writes complete!
# 2021-02-06
